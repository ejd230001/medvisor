# %%
import pandas as pd
import os
from PIL import Image
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 5
#       3 from PIL import Image
#       4 import numpy as np
# ----> 5 import tensorflow as tf
#       6 from tensorflow.keras.applications import ResNet50
#       7 from tensorflow.keras.models import Model
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
df = pd.read_csv("transformed_radiological_gradings.csv")

# %%
image_folder = "training_images"

# %%
image_list = []
label_list = []

for image_filename in os.listdir(image_folder):
    if image_filename.endswith(".png"):
        patient_id = int(image_filename.split('_')[0])
        patient_row = df[df['Patient'] == patient_id]
        image = Image.open(os.path.join(image_folder, image_filename))

        # Resize image to 224x224 pixels
        image_resized = image.resize((224,224))

        # Convert image to RGB
        image_recolored = image_resized.convert("RGB")

        # Convert the image to numpy array
        image_array = np.array(image_recolored)

        # Normalize array
        image_array_normalized = image_array / 255.0

        # Normalize for ImageNet
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        img_array_normalized = (image_array_normalized - mean) / std

        image_list.append(img_array_normalized)
        labels = patient_row.iloc[0].values[1:]
        label_list.append(labels)
        
        print(f"Image: {image_filename}, Patient Data: {patient_row.values}")
# Out:
# Image: 100_t1.png, Patient Data: [[100   2   1   1   0   0   1   1   2]]
# Image: 100_t2.png, Patient Data: [[100   2   1   1   0   0   1   1   2]]
# Image: 104_t1.png, Patient Data: [[104   2   1   1   0   0   1   1   4]]
# Image: 104_t2.png, Patient Data: [[104   2   1   1   0   0   1   1   4]]
# Image: 105_t1.png, Patient Data: [[105   0   1   1   0   1   1   1   3]]
# Image: 105_t2.png, Patient Data: [[105   0   1   1   0   1   1   1   3]]
# Image: 106_t1.png, Patient Data: [[106   2   1   1   0   1   1   1   4]]
# Image: 106_t2.png, Patient Data: [[106   2   1   1   0   1   1   1   4]]
# Image: 108_t1.png, Patient Data: [[108   0   1   1   0   0   1   1   3]]
# Image: 108_t2.png, Patient Data: [[108   0   1   1   0   0   1   1   3]]
# Image: 109_t1.png, Patient Data: [[109   0   1   1   1   1   1   0   2]]
# Image: 109_t2.png, Patient Data: [[109   0   1   1   1   1   1   0   2]]
# Image: 10_t1.png, Patient Data: [[10  2  1  1  0  1  1  1  4]]
# Image: 10_t2.png, Patient Data: [[10  2  1  1  0  1  1  1  4]]
# Image: 113_t1.png, Patient Data: [[113   0   1   1   0   0   1   1   2]]
# Image: 113_t2.png, Patient Data: [[113   0   1   1   0   0   1   1   2]]
# Image: 116_t1.png, Patient Data: [[116   2   1   1   0   0   1   1   4]]
# Image: 116_t2.png, Patient Data: [[116   2   1   1   0   0   1   1   4]]
# Image: 117_t1.png, Patient Data: [[117   2   1   1   1   0   1   1   3]]
# Image: 117_t2.png, Patient Data: [[117   2   1   1   1   0   1   1   3]]
# Image: 120_t2.png, Patient Data: [[120   0   0   0   0   1   1   1   2]]
# Image: 121_t1.png, Patient Data: [[121   2   1   0   0   0   1   1   2]]
# Image: 121_t2.png, Patient Data: [[121   2   1   0   0   0   1   1   2]]
# Image: 122_t1.png, Patient Data: [[122   0   0   0   0   0   0   1   1]]
# Image: 122_t2.png, Patient Data: [[122   0   0   0   0   0   0   1   1]]
# Image: 123_t2.png, Patient Data: [[123   0   1   0   0   1   1   1   2]]
# Image: 124_t2.png, Patient Data: [[124   0   1   1   0   1   1   1   3]]
# Image: 125_t1.png, Patient Data: [[125   0   1   0   0   0   1   1   3]]
# Image: 125_t2.png, Patient Data: [[125   0   1   0   0   0   1   1   3]]
# Image: 12_t1.png, Patient Data: [[12  0  0  0  0  1  1  1  2]]
# Image: 12_t2.png, Patient Data: [[12  0  0  0  0  1  1  1  2]]
# Image: 130_t1.png, Patient Data: [[130   2   1   1   1   0   1   1   4]]
# Image: 130_t2.png, Patient Data: [[130   2   1   1   1   0   1   1   4]]
# Image: 131_t1.png, Patient Data: [[131   0   0   0   0   0   1   1   2]]
# Image: 131_t2.png, Patient Data: [[131   0   0   0   0   0   1   1   2]]
# Image: 132_t1.png, Patient Data: [[132   0   0   1   0   0   1   1   1]]
# Image: 133_t1.png, Patient Data: [[133   2   0   0   1   0   1   1   3]]
# Image: 133_t2.png, Patient Data: [[133   2   0   0   1   0   1   1   3]]
# Image: 134_t2.png, Patient Data: [[134   0   1   1   0   0   1   1   2]]
# Image: 137_t1.png, Patient Data: [[137   0   1   1   0   0   1   0   2]]
# Image: 137_t2.png, Patient Data: [[137   0   1   1   0   0   1   0   2]]
# Image: 138_t1.png, Patient Data: [[138   0   0   0   0   0   1   1   2]]
# Image: 138_t2.png, Patient Data: [[138   0   0   0   0   0   1   1   2]]
# Image: 13_t1.png, Patient Data: [[13  2  1  1  1  0  1  1  4]]
# Image: 13_t2.png, Patient Data: [[13  2  1  1  1  0  1  1  4]]
# Image: 142_t1.png, Patient Data: [[142   0   1   1   1   1   1   1   4]]
# Image: 142_t2.png, Patient Data: [[142   0   1   1   1   1   1   1   4]]
# Image: 143_t1.png, Patient Data: [[143   2   1   1   0   0   1   1   4]]
# Image: 143_t2.png, Patient Data: [[143   2   1   1   0   0   1   1   4]]
# Image: 144_t1.png, Patient Data: [[144   0   1   1   0   1   1   1   2]]
# Image: 144_t2.png, Patient Data: [[144   0   1   1   0   1   1   1   2]]
# Image: 146_t1.png, Patient Data: [[146   2   1   1   0   1   1   1   4]]
# Image: 146_t2.png, Patient Data: [[146   2   1   1   0   1   1   1   4]]
# Image: 147_t2.png, Patient Data: [[147   0   1   1   0   1   1   1   3]]
# Image: 149_t1.png, Patient Data: [[149   0   1   1   0   0   0   1   1]]
# Image: 149_t2.png, Patient Data: [[149   0   1   1   0   0   0   1   1]]
# Image: 151_t2.png, Patient Data: [[151   0   0   0   0   0   1   1   2]]
# Image: 154_t1.png, Patient Data: [[154   2   1   1   0   1   1   1   3]]
# Image: 154_t2.png, Patient Data: [[154   2   1   1   0   1   1   1   3]]
# Image: 155_t1.png, Patient Data: [[155   2   1   1   0   0   1   1   3]]
# Image: 155_t2.png, Patient Data: [[155   2   1   1   0   0   1   1   3]]
# Image: 156_t1.png, Patient Data: [[156   2   1   1   1   1   1   1   4]]
# Image: 156_t2.png, Patient Data: [[156   2   1   1   1   1   1   1   4]]
# Image: 159_t2.png, Patient Data: [[159   0   1   1   0   1   1   1   3]]
# Image: 15_t1.png, Patient Data: [[15  2  1  1  0  1  1  1  3]]
# Image: 15_t2.png, Patient Data: [[15  2  1  1  0  1  1  1  3]]
# Image: 160_t1.png, Patient Data: [[160   0   1   1   0   0   1   1   3]]
# Image: 160_t2.png, Patient Data: [[160   0   1   1   0   0   1   1   3]]
# Image: 163_t1.png, Patient Data: [[163   2   1   1   1   0   1   1   3]]
# Image: 163_t2.png, Patient Data: [[163   2   1   1   1   0   1   1   3]]
# Image: 167_t1.png, Patient Data: [[167   0   1   1   0   0   1   1   2]]
# Image: 167_t2.png, Patient Data: [[167   0   1   1   0   0   1   1   2]]
# Image: 169_t1.png, Patient Data: [[169   2   1   1   0   0   1   1   3]]
# Image: 169_t2.png, Patient Data: [[169   2   1   1   0   0   1   1   3]]
# Image: 16_t1.png, Patient Data: [[16  0  0  1  1  0  1  1  2]]
# Image: 16_t2.png, Patient Data: [[16  0  0  1  1  0  1  1  2]]
# Image: 170_t1.png, Patient Data: [[170   2   1   1   0   0   1   1   2]]
# Image: 170_t2.png, Patient Data: [[170   2   1   1   0   0   1   1   2]]
# Image: 173_t1.png, Patient Data: [[173   2   1   1   0   1   1   1   2]]
# Image: 173_t2.png, Patient Data: [[173   2   1   1   0   1   1   1   2]]
# Image: 174_t1.png, Patient Data: [[174   0   0   0   0   1   0   0   2]]
# Image: 174_t2.png, Patient Data: [[174   0   0   0   0   1   0   0   2]]
# Image: 175_t1.png, Patient Data: [[175   0   1   1   0   1   1   1   2]]
# Image: 175_t2.png, Patient Data: [[175   0   1   1   0   1   1   1   2]]
# Image: 17_t1.png, Patient Data: [[17  0  0  0  0  0  1  1  2]]
# Image: 17_t2.png, Patient Data: [[17  0  0  0  0  0  1  1  2]]
# Image: 180_t1.png, Patient Data: [[180   0   1   1   0   0   1   1   1]]
# Image: 181_t1.png, Patient Data: [[181   2   1   1   0   0   1   1   5]]
# Image: 181_t2.png, Patient Data: [[181   2   1   1   0   0   1   1   5]]
# Image: 183_t2.png, Patient Data: [[183   0   1   1   0   1   1   1   3]]
# Image: 184_t1.png, Patient Data: [[184   0   1   1   1   0   1   1   2]]
# Image: 184_t2.png, Patient Data: [[184   0   1   1   1   0   1   1   2]]
# Image: 186_t1.png, Patient Data: [[186   2   1   1   0   1   1   1   5]]
# Image: 186_t2.png, Patient Data: [[186   2   1   1   0   1   1   1   5]]
# Image: 187_t1.png, Patient Data: [[187   0   0   1   0   0   0   1   2]]
# Image: 187_t2.png, Patient Data: [[187   0   0   1   0   0   0   1   2]]
# Image: 188_t1.png, Patient Data: [[188   0   1   1   0   0   0   0   2]]
# Image: 188_t2.png, Patient Data: [[188   0   1   1   0   0   0   0   2]]
# Image: 189_t1.png, Patient Data: [[189   0   1   1   0   0   1   1   2]]
# Image: 189_t2.png, Patient Data: [[189   0   1   1   0   0   1   1   2]]
# Image: 190_t1.png, Patient Data: [[190   0   0   0   0   0   0   0   1]]
# Image: 190_t2.png, Patient Data: [[190   0   0   0   0   0   0   0   1]]
# Image: 191_t1.png, Patient Data: [[191   0   1   1   0   0   1   1   4]]
# Image: 191_t2.png, Patient Data: [[191   0   1   1   0   0   1   1   4]]
# Image: 193_t1.png, Patient Data: [[193   0   0   0   0   0   1   1   1]]
# Image: 193_t2.png, Patient Data: [[193   0   0   0   0   0   1   1   1]]
# Image: 195_t1.png, Patient Data: [[195   0   0   0   0   0   1   1   2]]
# Image: 195_t2.png, Patient Data: [[195   0   0   0   0   0   1   1   2]]
# Image: 196_t1.png, Patient Data: [[196   2   1   1   1   0   0   0   2]]
# Image: 196_t2.png, Patient Data: [[196   2   1   1   1   0   0   0   2]]
# Image: 197_t2.png, Patient Data: [[197   0   1   1   0   0   1   1   4]]
# Image: 1_t1.png, Patient Data: [[1 0 0 1 0 0 1 1 4]]
# Image: 1_t2.png, Patient Data: [[1 0 0 1 0 0 1 1 4]]
# Image: 200_t1.png, Patient Data: [[200   0   0   0   1   0   1   1   2]]
# Image: 200_t2.png, Patient Data: [[200   0   0   0   1   0   1   1   2]]
# Image: 201_t2.png, Patient Data: [[201   0   1   1   0   1   1   1   3]]
# Image: 202_t1.png, Patient Data: [[202   0   1   1   0   0   1   1   2]]
# Image: 202_t2.png, Patient Data: [[202   0   1   1   0   0   1   1   2]]
# Image: 203_t1.png, Patient Data: [[203   0   1   1   0   0   0   1   3]]
# Image: 203_t2.png, Patient Data: [[203   0   1   1   0   0   0   1   3]]
# Image: 204_t1.png, Patient Data: [[204   0   1   1   0   0   1   1   3]]
# Image: 204_t2.png, Patient Data: [[204   0   1   1   0   0   1   1   3]]
# Image: 205_t1.png, Patient Data: [[205   0   0   0   0   0   0   1   2]]
# Image: 205_t2.png, Patient Data: [[205   0   0   0   0   0   0   1   2]]
# Image: 207_t1.png, Patient Data: [[207   2   0   0   0   0   1   1   2]]
# Image: 207_t2.png, Patient Data: [[207   2   0   0   0   0   1   1   2]]
# Image: 209_t1.png, Patient Data: [[209   0   1   1   1   1   1   1   3]]
# Image: 209_t2.png, Patient Data: [[209   0   1   1   1   1   1   1   3]]
# Image: 20_t2.png, Patient Data: [[20  0  1  1  0  0  1  1  3]]
# Image: 212_t1.png, Patient Data: [[212   0   1   1   1   1   1   1   4]]
# Image: 212_t2.png, Patient Data: [[212   0   1   1   1   1   1   1   4]]
# Image: 213_t1.png, Patient Data: [[213   0   1   1   0   1   1   1   2]]
# Image: 213_t2.png, Patient Data: [[213   0   1   1   0   1   1   1   2]]
# Image: 214_t1.png, Patient Data: [[214   0   1   1   0   1   1   1   2]]
# Image: 214_t2.png, Patient Data: [[214   0   1   1   0   1   1   1   2]]
# Image: 215_t1.png, Patient Data: [[215   0   1   1   0   0   0   1   1]]
# Image: 215_t2.png, Patient Data: [[215   0   1   1   0   0   0   1   1]]
# Image: 217_t1.png, Patient Data: [[217   0   0   0   0   0   1   1   3]]
# Image: 217_t2.png, Patient Data: [[217   0   0   0   0   0   1   1   3]]
# Image: 218_t1.png, Patient Data: [[218   0   1   1   1   0   1   1   1]]
# Image: 218_t2.png, Patient Data: [[218   0   1   1   1   0   1   1   1]]
# Image: 219_t1.png, Patient Data: [[219   0   1   1   0   0   1   1   1]]
# Image: 21_t2.png, Patient Data: [[21  0  1  1  0  0  1  1  3]]
# Image: 221_t1.png, Patient Data: [[221   2   1   1   0   0   1   1   3]]
# Image: 221_t2.png, Patient Data: [[221   2   1   1   0   0   1   1   3]]
# Image: 222_t1.png, Patient Data: [[222   0   1   1   0   1   1   1   3]]
# Image: 222_t2.png, Patient Data: [[222   0   1   1   0   1   1   1   3]]
# Image: 223_t1.png, Patient Data: [[223   0   1   1   0   1   1   1   2]]
# Image: 223_t2.png, Patient Data: [[223   0   1   1   0   1   1   1   2]]
# Image: 224_t1.png, Patient Data: [[224   0   1   1   0   0   1   1   3]]
# Image: 224_t2.png, Patient Data: [[224   0   1   1   0   0   1   1   3]]
# Image: 225_t1.png, Patient Data: [[225   0   1   1   0   0   1   1   3]]
# Image: 225_t2.png, Patient Data: [[225   0   1   1   0   0   1   1   3]]
# Image: 226_t1.png, Patient Data: [[226   2   1   1   0   0   1   1   4]]
# Image: 226_t2.png, Patient Data: [[226   2   1   1   0   0   1   1   4]]
# Image: 227_t1.png, Patient Data: [[227   0   1   1   0   0   1   1   3]]
# Image: 227_t2.png, Patient Data: [[227   0   1   1   0   0   1   1   3]]
# Image: 228_t1.png, Patient Data: [[228   0   0   1   0   0   1   1   2]]
# Image: 228_t2.png, Patient Data: [[228   0   0   1   0   0   1   1   2]]
# Image: 229_t1.png, Patient Data: [[229   0   1   1   0   0   1   1   3]]
# Image: 229_t2.png, Patient Data: [[229   0   1   1   0   0   1   1   3]]
# Image: 231_t1.png, Patient Data: [[231   0   1   1   0   0   1   1   3]]
# Image: 231_t2.png, Patient Data: [[231   0   1   1   0   0   1   1   3]]
# Image: 232_t1.png, Patient Data: [[232   0   0   0   0   0   0   1   2]]
# Image: 232_t2.png, Patient Data: [[232   0   0   0   0   0   0   1   2]]
# Image: 233_t1.png, Patient Data: [[233   0   0   0   0   1   1   1   2]]
# Image: 233_t2.png, Patient Data: [[233   0   0   0   0   1   1   1   2]]
# Image: 237_t1.png, Patient Data: [[237   0   0   0   0   0   0   0   1]]
# Image: 237_t2.png, Patient Data: [[237   0   0   0   0   0   0   0   1]]
# Image: 23_t1.png, Patient Data: [[23  2  1  1  1  1  1  1  4]]
# Image: 23_t2.png, Patient Data: [[23  2  1  1  1  1  1  1  4]]
# Image: 241_t1.png, Patient Data: [[241   0   1   1   0   1   1   1   4]]
# Image: 241_t2.png, Patient Data: [[241   0   1   1   0   1   1   1   4]]
# Image: 242_t1.png, Patient Data: [[242   0   1   1   0   0   1   1   2]]
# Image: 242_t2.png, Patient Data: [[242   0   1   1   0   0   1   1   2]]
# Image: 243_t1.png, Patient Data: [[243   0   0   0   0   0   1   1   1]]
# Image: 243_t2.png, Patient Data: [[243   0   0   0   0   0   1   1   1]]
# Image: 244_t1.png, Patient Data: [[244   2   1   1   0   0   1   1   4]]
# Image: 244_t2.png, Patient Data: [[244   2   1   1   0   0   1   1   4]]
# Image: 245_t1.png, Patient Data: [[245   0   0   0   0   0   1   1   4]]
# Image: 245_t2.png, Patient Data: [[245   0   0   0   0   0   1   1   4]]
# Image: 246_t2.png, Patient Data: [[246   0   1   1   0   0   1   1   3]]
# Image: 249_t1.png, Patient Data: [[249   2   1   1   0   0   1   1   3]]
# Image: 249_t2.png, Patient Data: [[249   2   1   1   0   0   1   1   3]]
# Image: 24_t1.png, Patient Data: [[24  2  1  1  0  1  1  1  4]]
# Image: 24_t2.png, Patient Data: [[24  2  1  1  0  1  1  1  4]]
# Image: 250_t1.png, Patient Data: [[250   0   0   0   0   0   1   1   3]]
# Image: 250_t2.png, Patient Data: [[250   0   0   0   0   0   1   1   3]]
# Image: 251_t1.png, Patient Data: [[251   0   1   0   0   1   1   1   4]]
# Image: 251_t2.png, Patient Data: [[251   0   1   0   0   1   1   1   4]]
# Image: 252_t1.png, Patient Data: [[252   0   0   0   0   1   1   0   2]]
# Image: 252_t2.png, Patient Data: [[252   0   0   0   0   1   1   0   2]]
# Image: 253_t1.png, Patient Data: [[253   0   1   1   1   0   1   1   4]]
# Image: 253_t2.png, Patient Data: [[253   0   1   1   1   0   1   1   4]]
# Image: 254_t1.png, Patient Data: [[254   0   0   0   0   1   1   1   3]]
# Image: 254_t2.png, Patient Data: [[254   0   0   0   0   1   1   1   3]]
# Image: 255_t1.png, Patient Data: [[255   0   1   1   0   1   1   1   2]]
# Image: 255_t2.png, Patient Data: [[255   0   1   1   0   1   1   1   2]]
# Image: 256_t1.png, Patient Data: [[256   0   1   1   0   1   1   1   2]]
# Image: 256_t2.png, Patient Data: [[256   0   1   1   0   1   1   1   2]]
# Image: 25_t1.png, Patient Data: [[25  0  1  1  0  0  1  1  3]]
# Image: 25_t2.png, Patient Data: [[25  0  1  1  0  0  1  1  3]]
# Image: 28_t1.png, Patient Data: [[28  0  1  1  0  0  1  1  2]]
# Image: 28_t2.png, Patient Data: [[28  0  1  1  0  0  1  1  2]]
# Image: 29_t1.png, Patient Data: [[29  2  1  1  1  1  1  1  4]]
# Image: 29_t2.png, Patient Data: [[29  2  1  1  1  1  1  1  4]]
# Image: 30_t1.png, Patient Data: [[30  0  1  1  0  0  1  1  3]]
# Image: 30_t2.png, Patient Data: [[30  0  1  1  0  0  1  1  3]]
# Image: 32_t1.png, Patient Data: [[32  0  1  1  0  1  1  0  2]]
# Image: 32_t2.png, Patient Data: [[32  0  1  1  0  1  1  0  2]]
# Image: 33_t1.png, Patient Data: [[33  2  1  1  0  1  1  1  3]]
# Image: 33_t2.png, Patient Data: [[33  2  1  1  0  1  1  1  3]]
# Image: 34_t2.png, Patient Data: [[34  0  0  1  0  0  1  1  4]]
# Image: 36_t1.png, Patient Data: [[36  0  0  0  1  0  1  1  3]]
# Image: 36_t2.png, Patient Data: [[36  0  0  0  1  0  1  1  3]]
# Image: 37_t1.png, Patient Data: [[37  0  1  1  0  0  1  1  3]]
# Image: 37_t2.png, Patient Data: [[37  0  1  1  0  0  1  1  3]]
# Image: 39_t1.png, Patient Data: [[39  0  1  1  0  0  1  0  2]]
# Image: 39_t2.png, Patient Data: [[39  0  1  1  0  0  1  0  2]]
# Image: 3_t1.png, Patient Data: [[3 0 0 0 0 0 1 1 4]]
# Image: 3_t2.png, Patient Data: [[3 0 0 0 0 0 1 1 4]]
# Image: 40_t1.png, Patient Data: [[40  0  1  1  0  0  0  0  1]]
# Image: 40_t2.png, Patient Data: [[40  0  1  1  0  0  0  0  1]]
# Image: 42_t2.png, Patient Data: [[42  0  0  0  0  0  1  1  1]]
# Image: 44_t1.png, Patient Data: [[44  0  1  1  1  1  1  1  3]]
# Image: 44_t2.png, Patient Data: [[44  0  1  1  1  1  1  1  3]]
# Image: 47_t1.png, Patient Data: [[47  0  1  1  0  0  1  1  2]]
# Image: 47_t2.png, Patient Data: [[47  0  1  1  0  0  1  1  2]]
# Image: 48_t1.png, Patient Data: [[48  0  1  1  0  0  0  1  3]]
# Image: 48_t2.png, Patient Data: [[48  0  1  1  0  0  0  1  3]]
# Image: 4_t1.png, Patient Data: [[4 2 1 1 1 1 1 1 3]]
# Image: 4_t2.png, Patient Data: [[4 2 1 1 1 1 1 1 3]]
# Image: 50_t1.png, Patient Data: [[50  0  1  1  1  1  1  1  4]]
# Image: 50_t2.png, Patient Data: [[50  0  1  1  1  1  1  1  4]]
# Image: 51_t1.png, Patient Data: [[51  0  1  1  0  0  1  1  3]]
# Image: 51_t2.png, Patient Data: [[51  0  1  1  0  0  1  1  3]]
# Image: 52_t2.png, Patient Data: [[52  0  0  0  0  0  1  1  3]]
# Image: 55_t2.png, Patient Data: [[55  0  1  1  1  0  1  1  3]]
# Image: 56_t1.png, Patient Data: [[56  0  1  1  0  1  1  1  2]]
# Image: 56_t2.png, Patient Data: [[56  0  1  1  0  1  1  1  2]]
# Image: 58_t1.png, Patient Data: [[58  2  1  1  0  0  1  1  4]]
# Image: 58_t2.png, Patient Data: [[58  2  1  1  0  0  1  1  4]]
# Image: 5_t1.png, Patient Data: [[5 0 0 0 0 0 0 1 2]]
# Image: 5_t2.png, Patient Data: [[5 0 0 0 0 0 0 1 2]]
# Image: 60_t1.png, Patient Data: [[60  0  1  1  0  0  1  1  3]]
# Image: 60_t2.png, Patient Data: [[60  0  1  1  0  0  1  1  3]]
# Image: 62_t1.png, Patient Data: [[62  0  1  1  1  1  1  1  3]]
# Image: 62_t2.png, Patient Data: [[62  0  1  1  1  1  1  1  3]]
# Image: 63_t1.png, Patient Data: [[63  2  1  1  1  0  1  1  3]]
# Image: 63_t2.png, Patient Data: [[63  2  1  1  1  0  1  1  3]]
# Image: 64_t1.png, Patient Data: [[64  0  0  1  0  0  1  1  2]]
# Image: 64_t2.png, Patient Data: [[64  0  0  1  0  0  1  1  2]]
# Image: 65_t1.png, Patient Data: [[65  2  1  1  0  0  1  1  4]]
# Image: 65_t2.png, Patient Data: [[65  2  1  1  0  0  1  1  4]]
# Image: 66_t1.png, Patient Data: [[66  0  1  1  0  0  0  1  2]]
# Image: 66_t2.png, Patient Data: [[66  0  1  1  0  0  0  1  2]]
# Image: 67_t1.png, Patient Data: [[67  0  0  0  0  1  0  1  2]]
# Image: 67_t2.png, Patient Data: [[67  0  0  0  0  1  0  1  2]]
# Image: 68_t1.png, Patient Data: [[68  2  1  1  0  0  1  1  5]]
# Image: 68_t2.png, Patient Data: [[68  2  1  1  0  0  1  1  5]]
# Image: 6_t2.png, Patient Data: [[6 0 0 0 0 0 1 1 2]]
# Image: 71_t1.png, Patient Data: [[71  2  1  1  1  0  1  1  4]]
# Image: 71_t2.png, Patient Data: [[71  2  1  1  1  0  1  1  4]]
# Image: 72_t1.png, Patient Data: [[72  0  1  1  0  0  1  1  1]]
# Image: 77_t1.png, Patient Data: [[77  0  0  0  0  0  0  0  1]]
# Image: 7_t1.png, Patient Data: [[7 0 0 1 1 0 1 1 3]]
# Image: 80_t1.png, Patient Data: [[80  0  1  1  1  1  1  1  3]]
# Image: 80_t2.png, Patient Data: [[80  0  1  1  1  1  1  1  3]]
# Image: 81_t1.png, Patient Data: [[81  0  1  1  0  0  1  1  3]]
# Image: 81_t2.png, Patient Data: [[81  0  1  1  0  0  1  1  3]]
# Image: 82_t1.png, Patient Data: [[82  2  1  1  1  0  1  1  5]]
# Image: 82_t2.png, Patient Data: [[82  2  1  1  1  0  1  1  5]]
# Image: 83_t1.png, Patient Data: [[83  2  1  1  0  0  1  1  3]]
# Image: 83_t2.png, Patient Data: [[83  2  1  1  0  0  1  1  3]]
# Image: 85_t1.png, Patient Data: [[85  2  1  1  0  0  1  1  5]]
# Image: 85_t2.png, Patient Data: [[85  2  1  1  0  0  1  1  5]]
# Image: 86_t1.png, Patient Data: [[86  2  1  1  0  0  1  1  3]]
# Image: 86_t2.png, Patient Data: [[86  2  1  1  0  0  1  1  3]]
# Image: 87_t1.png, Patient Data: [[87  0  1  1  0  0  1  1  2]]
# Image: 87_t2.png, Patient Data: [[87  0  1  1  0  0  1  1  2]]
# Image: 88_t1.png, Patient Data: [[88  2  1  1  0  0  1  1  4]]
# Image: 88_t2.png, Patient Data: [[88  2  1  1  0  0  1  1  4]]
# Image: 89_t2.png, Patient Data: [[89  0  0  1  0  1  1  1  3]]
# Image: 8_t1.png, Patient Data: [[8 0 0 0 0 0 1 1 3]]
# Image: 8_t2.png, Patient Data: [[8 0 0 0 0 0 1 1 3]]
# Image: 90_t1.png, Patient Data: [[90  0  1  1  0  0  1  1  4]]
# Image: 90_t2.png, Patient Data: [[90  0  1  1  0  0  1  1  4]]
# Image: 91_t2.png, Patient Data: [[91  0  1  1  0  0  1  1  3]]
# Image: 94_t1.png, Patient Data: [[94  0  0  0  0  0  1  1  2]]
# Image: 94_t2.png, Patient Data: [[94  0  0  0  0  0  1  1  2]]
# Image: 95_t1.png, Patient Data: [[95  0  1  1  0  1  0  0  1]]
# Image: 95_t2.png, Patient Data: [[95  0  1  1  0  1  0  0  1]]
# Image: 96_t1.png, Patient Data: [[96  0  1  1  0  0  1  1  2]]
# Image: 96_t2.png, Patient Data: [[96  0  1  1  0  0  1  1  2]]
# Image: 97_t2.png, Patient Data: [[97  0  1  1  0  0  1  1  4]]
# Image: 98_t1.png, Patient Data: [[98  0  1  1  0  1  1  0  4]]
# Image: 98_t2.png, Patient Data: [[98  0  1  1  0  1  1  0  4]]
# Image: 99_t2.png, Patient Data: [[99  0  1  1  0  1  1  1  3]]
# Image: 9_t1.png, Patient Data: [[9 2 1 1 0 0 1 1 4]]
# Image: 9_t2.png, Patient Data: [[9 2 1 1 0 0 1 1 4]]

# %%
img = Image.open("training_images/3_t1.png")
image_array = np.array(img)
print(image_array.shape)
# Out:
# (389, 320, 4)
